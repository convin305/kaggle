# %% [markdown]
# <a href="https://colab.research.google.com/github/convin305/kaggle/blob/main/%5Bkaggle_titanic2%5DEDA_To_Prediction(DieTanic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/code/ash316/eda-to-prediction-dietanic/notebook

# %%
# !pip install kaggle
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning이 발생하지 않도록 해줍니다.
# !chmod 600 ~/.kaggle/kaggle.json

# 데이터셋 다운로드
! kaggle competitions download -c titanic
# Out:
# ...
#      <input type="file" id="files-dab3435f-70ec-416d-bab1-d4d889169711" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dab3435f-70ec-416d-bab1-d4d889169711">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 28.0MB/s]

# %%
# !unzip titanic.zip
# Out:
# Archive:  titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 이거 뭔지 알아보기
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('/content/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() # 결측치 확인
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age, Cabin, Embarked에 결측치 존재

# %%
# 얼마나 생존했는지 시각화 
f, ax = plt.subplots(1,2,figsize = (18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct = '%1.1f%%',ax = ax[0],shadow = True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
## Sex
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data = data, ax=ax[1])
ax[1].set_title('Sex : Survived vs Dead')
plt.show()

# %%
## Pclass
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7e065_row0_col0, #T_7e065_row1_col1, #T_7e065_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7e065_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_7e065_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_7e065_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_7e065_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_7e065_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_7e065_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_7e065_row3_col0, #T_7e065_row3_col1, #T_7e065_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e065_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data = data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# 그냥 웃긴 점 : 돈으로 뭐든지 다 살 수 는 없다고 말하지만~ 생존 확률을 높일수는 있다!

# %%
## Sex and Pclass
pd.crosstab([data.Sex, data.Survived],data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_4dea3_row0_col0, #T_4dea3_row0_col1, #T_4dea3_row0_col3, #T_4dea3_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4dea3_row0_col2, #T_4dea3_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_4dea3_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_4dea3_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_4dea3_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_4dea3_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_4dea3_row2_col1, #T_4dea3_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_4dea3_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_4dea3_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_4dea3_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_4dea3_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data = data)
plt.show()

# %%
## Age
print(f'Oldest Passenger was of : {max(data.Age)} Years')
print(f'Youngest Passenger was of  : {min(data.Age)} Years')
print(f'Average Age on the ship : {data.Age.mean() } Years')
# Out:
# Oldest Passenger was of : 80.0 Years
# Youngest Passenger was of  : 0.42 Years
# Average Age on the ship : 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# * 어린이의 수는 Pclass에 따라서 증가, 10세 미만의 생존율은 Pclass에 상관없이 양호함.
# * Pclass1의 20~50세 생존율은 높으며, 여성일수록 더 좋음
# * 남성의 경우 생존율은 나이가 증가함에 따라 감소함.

# %%
# 나이를 채우기 위해서 이름을 활용
data['Initial'] = 0
for i in data:
  data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
# 이거 신박하다ㅣ바
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap = 'summer_r')
# Out:
# <style type="text/css">
# #T_d48f6_row0_col0, #T_d48f6_row0_col1, #T_d48f6_row0_col3, #T_d48f6_row0_col4, #T_d48f6_row0_col5, #T_d48f6_row0_col7, #T_d48f6_row0_col8, #T_d48f6_row0_col12, #T_d48f6_row0_col15, #T_d48f6_row0_col16, #T_d48f6_row1_col2, #T_d48f6_row1_col6, #T_d48f6_row1_col9, #T_d48f6_row1_col10, #T_d48f6_row1_col11, #T_d48f6_row1_col13, #T_d48f6_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d48f6_row0_col2, #T_d48f6_row0_col6, #T_d48f6_row0_col9, #T_d48f6_row0_col10, #T_d48f6_row0_col11, #T_d48f6_row0_col13, #T_d48f6_row0_col14, #T_d48f6_row1_col0, #T_d48f6_row1_col1, #T_d48f6_row1_col3, #T_d48f6_row1_col4, #T_d48f6_row1_col5, #T_d48f6_row1_col7, #T_d48f6_row1_col8, #T_d48f6_row1_col12, #T_d48f6_row1_col15, #T_d48f6_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d48f6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64
